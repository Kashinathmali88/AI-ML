# %%
# Api 
import requests as rq

# %%
URL = "https://dragonball-api.com/api/characters?page=2&limit=5"
res = rq.get(URL)
json_data = res.json()

# %%
import pandas as pd

df = pd.json_normalize(json_data["items"])
df
# Out:
#    id     name           ki          maxKi         race gender  \
# 0   6   Zarbon       20.000         30.000  Frieza Race   Male
# 1   7  Dodoria       18.000         20.000  Frieza Race   Male
# 2   8    Ginyu        9.000         25.000  Frieza Race   Male
# 3   9   Celula  250.000.000      5 Billion      Android   Male
# 4  10    Gohan   45.000.000  40 septillion       Saiyan   Male
#
#                                          description  \
# 0  Zarbon es uno de los secuaces de Freezer y un ...
# 1  Dodoria es otro secuaz de Freezer conocido por...
# 2  Ginyu es el líder del la élite de mercenarios ...
# 3  Cell conocido como Célula en España, es un bio...
# 4  Son Gohanda en su tiempo en España, o simpleme...
#
#                                                image     affiliation deletedAt
# 0  https://dragonball-api.com/characters/zarbon.webp  Army of Frieza      None
# 1  https://dragonball-api.com/characters/dodoria....  Army of Frieza      None
# 2   https://dragonball-api.com/characters/ginyu.webp  Army of Frieza      None
# 3  https://dragonball-api.com/characters/celula.webp      Freelancer      None
# 4   https://dragonball-api.com/characters/gohan.webp       Z Fighter      None

# %%
# Web Scraping

import requests as rq

URL = "https://dragonball-api.com/api/characters?page=2&limit=5"
